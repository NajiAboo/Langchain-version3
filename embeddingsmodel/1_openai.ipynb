# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]
# Out:
# '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'

# %%
from langchain_openai import OpenAIEmbeddings

# %%
emb = OpenAIEmbeddings(model="text-embedding-3-small", dimensions=1024)

# %%
text ="I am teaching langchain"

# %%
r1 = emb.embed_query(text=text)

# %%
len(r1)
# Out:
# 1024

# %%
r1
# Out:
# [0.002954319817945361,
#  -0.014763323590159416,
#  0.024428997188806534,
#  -0.012090367265045643,
#  0.012404832988977432,
#  -0.0025943396613001823,
#  0.0045431978069245815,
#  0.060443561524152756,
#  -0.09003641456365585,
#  0.014101291075348854,
#  0.051506124436855316,
#  -0.023899370804429054,
#  -0.032058920711278915,
#  0.022327043116092682,
#  0.030999669805169106,
#  0.005817609839141369,
#  -0.021648460999131203,
#  0.0015381909906864166,
#  0.005552797112613916,
#  0.07864945381879807,
#  -0.017990730702877045,
#  -0.03846408426761627,
#  0.01684045046567917,
#  0.06332340091466904,
#  0.018090035766363144,
#  -0.02679576352238655,
#  0.05796093866229057,
#  0.035220127552747726,
#  -0.008622972294688225,
#  -0.00791542511433363,
#  0.02224428951740265,
#  -0.045216817408800125,
#  -0.028301887214183807,
#  0.014283349737524986,
#  -0.016799073666334152,
#  0.01646805740892887,
#  0.01810658723115921,
#  0.0440913587808609,
#  -0.007141674868762493,
# ...
